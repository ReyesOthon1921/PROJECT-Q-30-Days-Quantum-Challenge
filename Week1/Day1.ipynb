# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)
qc.h(0)

print("PROJECT-Q Day 1 Ready")
# Out:
# PROJECT-Q Day 1 Ready

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# C:\Users\reyes\QuantumResearch\qenv\Scripts\python.exe
# 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]

# %%
qc.draw("text")
# Out:
#    ┌───┐
# q: ┤ H ├
#    └───┘

# %% [markdown]
# ## Learning Objectives
#
# Today marked the beginning of my Project-Q 30-Day Quantum Computing Challenge. My goal was to build a strong conceptual foundation by understanding the principles that distinguish quantum computing from classical computing.
#
# By the end of Day 1, I wanted to understand:
#
# - Why quantum computing exists.
# - How qubits differ from classical bits.
# - What superposition means.
# - The concept of entanglement.
# - How interference contributes to quantum algorithms.
# - Why decoherence is a major challenge in quantum computing.
# - The IBM Quantum Learning Ecosystem.
# - How Qiskit allows quantum programming using Python.

# %% [markdown]
# page 1 - ![image.png](attachment:4b99b13a-6986-4dbe-af80-796cf30b35c7.png)

# %% [markdown]
# page 2 - ![image.png](attachment:0544ba36-3818-49f1-9264-6ad60d22d8e2.png)
